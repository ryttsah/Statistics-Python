# %% [markdown]
# # Lists and Tuples <hr style ="border:2.5px solid #673886ff">

# %% [markdown]
# <b>Perez, Harold A.
# <br>Computer Engineering Technology

# %% [markdown]
# # Creating a List

# %%
numbers = [1, 2, 3, 4, 5]
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = ["apple", "banana", "cherry"]
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
mixed_list = [1, "hello", 3.14, True]
mixed_list
# Out:
# [1, 'hello', 3.14, True]

# %% [markdown]
# # Indexing

# %%
numbers = [1, 2, 3, 4, 5]
numbers[2]
# Out:
# 3

# %%
numbers[-3]
# Out:
# 3

# %% [markdown]
# # Modifying Elements

# %%
fruits = ["apple", "banana", "grape"]
fruits[0] = "orange"
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
fruits[-2] = "blueberry"
fruits
# Out:
# ['orange', 'blueberry', 'grape']

# %% [markdown]
# # Adding elements

# %%
fruits = ["apple", "banana", "grape"]
fruits.append("orange")
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1, "kiwi")
fruits
# Out:
# ['apple', 'kiwi', 'blueberry', 'banana', 'grape', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ["apple", "banana", "grape"]
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
'orange' in fruits
# Out:
# False

# %%
fruits.remove("banana")
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
fruits
# Out:
# ['grape']

# %% [markdown]
# # Sort and Sorted

# %%
numbers = [1, 3, 4, 7, 5, 2, 6]
numbers
# Out:
# [1, 3, 4, 7, 5, 2, 6]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
numbers
# Out:
# [1, 3, 4, 7, 5, 2, 6]

# %%
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# # Slicing

# %%
numbers = [2, 3, 3, 1, 4, 2, 5, 1, 9]
numbers
# Out:
# [2, 3, 3, 1, 4, 2, 5, 1, 9]

# %%
len(numbers)
# Out:
# 9

# %%
sub = numbers[1:5]
sub
# Out:
# [3, 3, 1, 4]

# %%
numbers[0:9:2]
# Out:
# [2, 3, 4, 5, 9]

# %% [markdown]
# # Tuple

# %%
my_tuple = (1, 2, 3, 4, 5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[1]

# %%
my_tuple = (1, 2, 3, 4, 5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)
